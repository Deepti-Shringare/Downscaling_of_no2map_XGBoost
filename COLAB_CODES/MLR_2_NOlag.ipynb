# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# ML Libraries
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from scipy.stats import pearsonr

print("✓ All libraries imported successfully")

# ============================================================================
# 0. CUSTOM METRICS
# ============================================================================

def compute_metrics(y_true, y_pred, label=""):
    """
    Compute comprehensive evaluation metrics:
    R², RMSE, MAE, MBE, NMB, Pearson r, MAPE, IOA
    """
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    r2   = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae  = mean_absolute_error(y_true, y_pred)

    # Mean Bias Error (positive = model over-predicts)
    mbe  = np.mean(y_pred - y_true)

    # Normalised Mean Bias  (MBE / mean_observed)
    nmb  = mbe / np.mean(y_true) if np.mean(y_true) != 0 else np.nan

    # Pearson correlation
    r_val, p_val = pearsonr(y_true, y_pred)

    # Mean Absolute Percentage Error
    mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-9))) * 100

    # Index of Agreement (Willmott 1981)
    num   = np.sum((y_true - y_pred) ** 2)
    denom = np.sum((np.abs(y_pred - np.mean(y_true)) +
                    np.abs(y_true - np.mean(y_true))) ** 2)
    ioa   = 1 - num / denom if denom != 0 else np.nan

    metrics = dict(
        R2=r2, RMSE=rmse, MAE=mae,
        MBE=mbe, NMB=nmb,
        Pearson_r=r_val, MAPE=mape, IOA=ioa
    )

    if label:
        print(f"\n{'─'*60}")
        print(f"  METRICS: {label}")
        print(f"{'─'*60}")
        print(f"  R²          : {r2:.4f}")
        print(f"  RMSE        : {rmse:.4f} µg/m³")
        print(f"  MAE         : {mae:.4f} µg/m³")
        print(f"  MBE         : {mbe:.4f} µg/m³  (+ = over-predict)")
        print(f"  NMB         : {nmb:.4f}         (fraction)")
        print(f"  Pearson r   : {r_val:.4f}  (p={p_val:.2e})")
        print(f"  MAPE        : {mape:.2f} %")
        print(f"  IOA         : {ioa:.4f}")

    return metrics


def compute_spatial_r2(df_test_with_meta, y_pred, station_col='station'):
    """
    Spatial R²: per-station mean observed vs per-station mean predicted.
    Measures whether the model captures the spatial gradient.
    """
    tmp = df_test_with_meta[['groundtruth_no2', station_col]].copy()
    tmp['y_pred'] = y_pred

    agg = tmp.groupby(station_col).agg(
        obs_mean=('groundtruth_no2', 'mean'),
        pred_mean=('y_pred', 'mean')
    )

    spatial_r2 = r2_score(agg['obs_mean'], agg['pred_mean'])
    r_val, _ = pearsonr(agg['obs_mean'], agg['pred_mean'])

    print(f"\n  Spatial R²  : {spatial_r2:.4f}  (n_stations={len(agg)})")
    print(f"  Spatial r   : {r_val:.4f}")
    return spatial_r2, r_val


def compute_temporal_r2(df_test_with_meta, y_pred, date_col='date'):
    """
    Temporal R²: per-day mean observed vs per-day mean predicted.
    Measures whether the model captures the temporal trend.
    """
    tmp = df_test_with_meta[['groundtruth_no2', date_col]].copy()
    tmp['y_pred'] = y_pred

    agg = tmp.groupby(date_col).agg(
        obs_mean=('groundtruth_no2', 'mean'),
        pred_mean=('y_pred', 'mean')
    )

    temporal_r2 = r2_score(agg['obs_mean'], agg['pred_mean'])
    r_val, _ = pearsonr(agg['obs_mean'], agg['pred_mean'])

    print(f"  Temporal R² : {temporal_r2:.4f}  (n_days={len(agg)})")
    print(f"  Temporal r  : {r_val:.4f}")
    return temporal_r2, r_val


# ============================================================================
# 1. DATA LOADING AND PREPROCESSING
# ============================================================================

def load_and_preprocess_data(filepath):
    """
    Load and preprocess the master dataset
    """
    print("\n" + "=" * 80)
    print("STEP 1: LOADING DATA")
    print("=" * 80)

    df = pd.read_csv(filepath)
    print(f"✓ Data loaded successfully")
    print(f"  - Rows: {df.shape[0]:,}")
    print(f"  - Columns: {df.shape[1]}")
    print(f"  - Stations: {df['station'].nunique()}")

    df['date'] = pd.to_datetime(df['date'])
    print(f"✓ Date converted to datetime")
    print(f"  - Date range: {df['date'].min()} to {df['date'].max()}")
    print(f"  - Total days: {(df['date'].max() - df['date'].min()).days}")

    print("\n✓ Sample of your data:")
    print(df.head(3).to_string())

    print("\n" + "-" * 80)
    print("DATA QUALITY CHECK")
    print("-" * 80)
    missing = df.isnull().sum()
    if missing.sum() > 0:
        print("Missing values found:")
        for col in missing[missing > 0].index:
            pct = (missing[col] / len(df)) * 100
            print(f"  - {col}: {missing[col]:,} ({pct:.1f}%)")
    else:
        print("✓ No missing values found!")

    return df


# ============================================================================
# 2. MISSING VALUE HANDLING  ── ML-based gap filling (no mean imputation)
# ============================================================================

def handle_missing_values(df):
    """
    Handle missing values in the dataset.

    Strategy for tropospheric_no2 (satellite gaps due to clouds):
    ─────────────────────────────────────────────────────────────
    1.  Add `satellite_missing_flag` = 1 where NO₂ is NaN.
    2.  Build a small auxiliary Ridge regression trained ONLY on rows
        where tropospheric_no2 is observed (flag = 0).
    3.  Use the auxiliary model to PREDICT the missing rows.
    4.  Replace ONLY those missing rows with the ML prediction.
        → True gap reconstruction; no mean-based imputation.
    """
    print("\n" + "=" * 80)
    print("STEP 2: HANDLING MISSING VALUES  (ML-based gap filling)")
    print("=" * 80)

    initial_rows = len(df)

    # ── Remove rows where target is missing ──────────────────────────────────
    df = df.dropna(subset=['groundtruth_no2'])
    removed = initial_rows - len(df)
    if removed > 0:
        print(f"✓ Removed {removed:,} rows with missing groundtruth_no2")
    else:
        print("✓ No missing values in groundtruth_no2")

    # ── satellite_missing_flag ───────────────────────────────────────────────
    df['satellite_missing_flag'] = df['tropospheric_no2'].isnull().astype(int)
    missing_count = df['satellite_missing_flag'].sum()

    if missing_count > 0:
        print(f"\n✓ {missing_count:,} rows have missing tropospheric_no2 (cloudy days)")
        print("  → Training auxiliary Ridge model to reconstruct gaps …")

        # Proxy predictors available on ALL rows (no satellite column)
        gap_proxy_cols = [
            c for c in df.columns
            if c not in ['station', 'date', 'groundtruth_no2',
                         'tropospheric_no2', 'satellite_missing_flag']
            and df[c].dtype in [np.float64, np.float32, np.int64, np.int32, int, float]
        ]

        obs_mask = df['satellite_missing_flag'] == 0
        gap_mask = df['satellite_missing_flag'] == 1

        # Restrict proxy cols to those with no NaN in EITHER the observed
        # OR the gap portion — guarantees X_obs and X_gap are both NaN-free.
        # If a column still has NaN in gap rows (e.g. single missing BLH/cloud),
        # the SimpleImputer in the pipeline handles it as a last resort.
        valid_proxy = [
            c for c in gap_proxy_cols
            if df.loc[obs_mask, c].isnull().sum() == 0
            and df.loc[gap_mask, c].isnull().sum() == 0
        ]

        # If no perfectly clean columns found, fall back to all proxy cols
        # and let the imputer handle residual NaNs.
        if not valid_proxy:
            valid_proxy = gap_proxy_cols

        X_obs = df.loc[obs_mask, valid_proxy].copy()
        y_obs = df.loc[obs_mask, 'tropospheric_no2'].copy()

        X_gap = df.loc[gap_mask, valid_proxy].copy()

        aux_model = Pipeline([
            ('imputer', SimpleImputer(strategy='median')),   # safety net for any stray NaN
            ('scaler',  StandardScaler()),
            ('ridge',   Ridge(alpha=1.0))
        ])
        aux_model.fit(X_obs, y_obs)

        gap_preds = aux_model.predict(X_gap)
        # Clip to physically plausible range
        gap_preds = np.clip(gap_preds, 0, None)

        df.loc[gap_mask, 'tropospheric_no2'] = gap_preds

        aux_r2 = r2_score(y_obs, aux_model.predict(X_obs))
        print(f"  ✓ Auxiliary model train R² = {aux_r2:.3f}")
        print(f"  ✓ Replaced {missing_count:,} missing satellite values with ML predictions")
    else:
        print("✓ No missing satellite data")

    # ── Any remaining NaN in other predictors ────────────────────────────────
    predictor_cols = [col for col in df.columns
                      if col not in ['station', 'date', 'groundtruth_no2']]
    remaining_missing = df[predictor_cols].isnull().sum().sum()
    if remaining_missing > 0:
        print(f"\n⚠ Warning: {remaining_missing} missing values in other features")
        print("  - Filling with column means (last resort) …")
        df[predictor_cols] = df[predictor_cols].fillna(df[predictor_cols].mean())
        print("  ✓ Done")

    print(f"\n✓ Final dataset: {len(df):,} rows ready for modeling")
    return df


# ============================================================================
# 3. FEATURE ENGINEERING  (lag features REMOVED; spatial neighbor ADDED)
# ============================================================================

def create_features(df):
    """
    Create additional features.
    ─ Lag / moving-average features: REMOVED
    ─ Spatial neighbor feature (spatial_lag_no2): ADDED
    """
    print("\n" + "=" * 80)
    print("STEP 3: FEATURE ENGINEERING")
    print("=" * 80)

    initial_features = len(df.columns)

    # ── 1. TEMPORAL FEATURES ─────────────────────────────────────────────────
    print("\n1. Creating temporal features …")
    df['year']               = df['date'].dt.year
    df['month']              = df['date'].dt.month
    df['day']                = df['date'].dt.day
    df['day_of_year']        = df['date'].dt.dayofyear
    df['day_of_week']        = df['date'].dt.dayofweek
    df['is_weekend']         = (df['day_of_week'] >= 5).astype(int)

    df['season'] = df['month'].apply(lambda x:
        'winter' if x in [12, 1, 2] else
        'spring' if x in [3, 4, 5] else
        'summer' if x in [6, 7, 8] else
        'autumn')
    season_map = {'winter': 1, 'spring': 2, 'summer': 3, 'autumn': 4}
    df['season_numeric']     = df['season'].map(season_map)

    df['is_critical_winter'] = df['month'].apply(lambda x: 1 if x in [11, 12, 1, 2] else 0)
    print("   ✓ Added 8 temporal features")

    # ── 2. METEOROLOGICAL FEATURES ───────────────────────────────────────────
    print("\n2. Creating meteorological features …")
    df['wind_direction']   = (np.degrees(np.arctan2(df['v10'], df['u10'])) + 360) % 360
    df['stability_index']  = df['BLH'] / (df['wind_speed'] + 0.1)
    df['ventilation_coef'] = df['BLH'] * df['wind_speed']
    df['temp_category'] = pd.cut(df['temperature_2m_C'],
                                  bins=[-np.inf, 15, 25, np.inf],
                                  labels=['cold', 'moderate', 'hot'])
    df['is_cold'] = (df['temperature_2m_C'] < 15).astype(int)
    df['is_hot']  = (df['temperature_2m_C'] > 30).astype(int)
    print("   ✓ Added 7 meteorological features")

    # ── 3. EMISSION PROXY FEATURES ───────────────────────────────────────────
    print("\n3. Creating emission proxy features …")
    df['urban_intensity']     = df['population_density'] * df['night_light']
    df['urban_intensity_log'] = np.log1p(df['urban_intensity'])
    print("   ✓ Added 2 emission proxy features")

    # ── 4. SPATIAL FEATURES ──────────────────────────────────────────────────
    print("\n4. Creating spatial features …")
    delhi_center_lat, delhi_center_lon = 28.6139, 77.2090
    df['dist_from_center'] = np.sqrt(
        (df['lat'] - delhi_center_lat) ** 2 +
        (df['lon'] - delhi_center_lon) ** 2
    ) * 111
    print("   ✓ Added 1 distance feature")

    # ── 5. SPATIAL NEIGHBOR FEATURE (spatial_lag_no2) ─────────────────────────
    print("\n5. Creating spatial neighbor feature (spatio-temporal) …")
    print("   Computing mean tropospheric_no2 of adjacent stations on the same day …")

    # Sort for reproducibility
    df = df.sort_values(['date', 'station']).reset_index(drop=True)

    # Round coords to 2 dp to group neighbours in a grid-like sense
    df['_lat_r'] = df['lat'].round(2)
    df['_lon_r'] = df['lon'].round(2)

    # For each (date, station) compute mean NO₂ of stations within ±0.05° (~5 km)
    spatial_lag_vals = []
    station_coords = df[['station', 'lat', 'lon']].drop_duplicates().set_index('station')

    # Precompute per-station daily tropospheric_no2
    daily_station = df.groupby(['date', 'station'])['tropospheric_no2'].mean()

    for idx, row in df.iterrows():
        target_lat  = row['lat']
        target_lon  = row['lon']
        target_date = row['date']
        target_sta  = row['station']

        # Euclidean degree distance to all other stations
        dist = np.sqrt(
            (station_coords['lat'] - target_lat) ** 2 +
            (station_coords['lon'] - target_lon) ** 2
        )
        # Neighbours within 0.1 degrees (~11 km) excluding self
        neighbours = dist[(dist <= 0.10) & (dist.index != target_sta)].index.tolist()

        if neighbours:
            vals = []
            for n in neighbours:
                key = (target_date, n)
                if key in daily_station.index:
                    vals.append(daily_station[key])
            spatial_lag_vals.append(np.mean(vals) if vals else np.nan)
        else:
            spatial_lag_vals.append(np.nan)

    df['spatial_lag_no2'] = spatial_lag_vals

    # Fill any remaining NaN in spatial_lag with station-level mean
    df['spatial_lag_no2'] = df.groupby('station')['spatial_lag_no2'].transform(
        lambda x: x.fillna(x.mean())
    )
    df['spatial_lag_no2'] = df['spatial_lag_no2'].fillna(df['tropospheric_no2'])

    # Drop temporary rounded columns
    df.drop(columns=['_lat_r', '_lon_r'], inplace=True)

    print("   ✓ Added 1 spatial_lag_no2 feature  (true spatio-temporal signal)")

    # ── 6. INTERACTION FEATURES ──────────────────────────────────────────────
    print("\n6. Creating interaction features …")
    df['satellite_stability']    = df['tropospheric_no2'] * df['stability_index']
    df['cloud_temp_interaction'] = df['total_cloud_cover'] * (1 / (df['temperature_2m_C'] + 1))
    print("   ✓ Added 2 interaction features")

    final_features = len(df.columns)
    print("\n" + "-" * 80)
    print(f"✓ FEATURE ENGINEERING COMPLETE")
    print(f"  - Started with: {initial_features} columns")
    print(f"  - Created: {final_features - initial_features} new features")
    print(f"  - Total features: {final_features} columns")
    print("  ✗ Lag / moving-average features: NOT added (removed as requested)")
    print("  ✓ spatial_lag_no2: ADDED (true spatio-temporal feature)")
    print("-" * 80)

    return df


# ============================================================================
# 4. DATA PREPARATION  (unchanged split strategy)
# ============================================================================

def prepare_train_test_split(df, random_state=42):
    """
    Temporal + Spatial validation split.
    Train: Mar–Nov (non-winter); Test: Dec–Feb + 5 held-out stations.
    """
    print("\n" + "=" * 80)
    print("STEP 4: PREPARING TRAIN-TEST SPLIT")
    print("=" * 80)
    print("\n⚠️  ADVANCED VALIDATION STRATEGY:")
    print("   1. TEMPORAL SPLIT: Train on Mar-Nov, Test on Dec-Feb (winter)")
    print("   2. SPATIAL SPLIT : 5 stations held out for testing")
    print("=" * 80)

    exclude_cols = [
        'station', 'date', 'groundtruth_no2',
        'season', 'temp_category'
    ]
    feature_cols = [col for col in df.columns if col not in exclude_cols]

    print(f"\n✓ Selected {len(feature_cols)} features for modeling")

    temporal_features  = [f for f in feature_cols if any(x in f for x in ['year','month','day','season','weekend','winter'])]
    meteo_features     = [f for f in feature_cols if any(x in f for x in ['wind','temp','pressure','BLH','cloud','stability','ventilation'])]
    spatial_features   = [f for f in feature_cols if any(x in f for x in ['lat','lon','dist','population','night','urban','spatial_lag'])]
    satellite_features = [f for f in feature_cols if 'tropospheric' in f or 'satellite' in f]

    print("Feature categories:")
    print(f"  - Temporal:          {len(temporal_features)}")
    print(f"  - Meteorological:    {len(meteo_features)}")
    print(f"  - Spatial/Emission:  {len(spatial_features)}")
    print(f"  - Satellite:         {len(satellite_features)}")
    print(f"  - Lag/Moving Avg:    0  (removed as requested)")

    df_clean = df.dropna(subset=feature_cols + ['groundtruth_no2'])
    removed_rows = len(df) - len(df_clean)
    if removed_rows > 0:
        print(f"\n✓ Removed {removed_rows:,} rows with NaN after feature engineering")

    # ── SPATIAL SPLIT ────────────────────────────────────────────────────────
    print("\n" + "-" * 80)
    print("SPATIAL SPLIT: Selecting test-only stations")
    all_stations = df_clean['station'].unique()
    np.random.seed(random_state)
    test_stations = np.random.choice(all_stations, size=5, replace=False)

    print(f"✓ Total stations: {len(all_stations)}")
    print(f"✓ Stations reserved for TESTING ONLY:")
    for i, s in enumerate(test_stations, 1):
        print(f"   {i}. {s}")

    spatial_test_mask  = df_clean['station'].isin(test_stations)
    df_spatial_train   = df_clean[~spatial_test_mask].copy()
    df_spatial_test    = df_clean[spatial_test_mask].copy()

    # ── TEMPORAL SPLIT ───────────────────────────────────────────────────────
    print("\n" + "-" * 80)
    print("TEMPORAL SPLIT: Train on Mar-Nov, Test on Dec-Feb")
    train_months = [3, 4, 5, 6, 7, 8, 9, 10, 11]
    test_months  = [12, 1, 2]

    df_temporal_train          = df_spatial_train[df_spatial_train['month'].isin(train_months)].copy()
    df_temporal_test_same_sta  = df_spatial_train[df_spatial_train['month'].isin(test_months)].copy()
    df_test_combined           = pd.concat([df_temporal_test_same_sta, df_spatial_test], axis=0)

    print(f"✓ Training samples (Mar-Nov):            {len(df_temporal_train):,}")
    print(f"✓ Temporal test (Dec-Feb, train sta.):   {len(df_temporal_test_same_sta):,}")
    print(f"✓ Spatial test  (all months, 5 sta.):    {len(df_spatial_test):,}")
    print(f"✓ Total test samples:                    {len(df_test_combined):,}")

    X_train = df_temporal_train[feature_cols]
    y_train = df_temporal_train['groundtruth_no2']
    X_test  = df_test_combined[feature_cols]
    y_test  = df_test_combined['groundtruth_no2']

    print(f"\n✓ TRAINING SET: {len(X_train):,} samples | NO2 mean={y_train.mean():.2f}")
    print(f"✓ TESTING  SET: {len(X_test):,}  samples | NO2 mean={y_test.mean():.2f}")
    print("\n" + "=" * 80)
    print("✓ DATA SPLIT COMPLETE - NO DATA LEAKAGE GUARANTEED")
    print("=" * 80)

    test_station_info = {
        'test_stations':  test_stations.tolist(),
        'train_stations': df_temporal_train['station'].unique().tolist()
    }

    # Return df_test_combined for spatial/temporal metric computation
    return X_train, X_test, y_train, y_test, feature_cols, test_station_info, df_test_combined


# ============================================================================
# 5. LINEAR REGRESSION MODELS  (OLS, Ridge, Lasso)
# ============================================================================

def train_ols(X_train, y_train, X_test, y_test):
    """Ordinary Least Squares (OLS) Linear Regression"""
    print("\n" + "=" * 80)
    print("STEP 5A: TRAINING OLS LINEAR REGRESSION")
    print("=" * 80)

    model = Pipeline([
        ('scaler', StandardScaler()),
        ('ols',    LinearRegression())
    ])
    model.fit(X_train, y_train)

    y_pred_train = model.predict(X_train)
    y_pred_test  = model.predict(X_test)

    train_r2 = r2_score(y_train, y_pred_train)
    print(f"\n  Training R²: {train_r2:.4f}")
    compute_metrics(y_test, y_pred_test, label="OLS – Test Set")

    if test_r2 := r2_score(y_test, y_pred_test):
        if test_r2 > 0.75:
            print("  ✓ EXCELLENT")
        elif test_r2 > 0.65:
            print("  ✓ GOOD")
        else:
            print("  ⚠ FAIR")

    return model, y_pred_test


def train_ridge(X_train, y_train, X_test, y_test, alpha=1.0):
    """Ridge Regression (L2 regularisation)"""
    print("\n" + "=" * 80)
    print(f"STEP 5B: TRAINING RIDGE REGRESSION  (alpha={alpha})")
    print("=" * 80)

    model = Pipeline([
        ('scaler', StandardScaler()),
        ('ridge',  Ridge(alpha=alpha))
    ])
    model.fit(X_train, y_train)

    y_pred_train = model.predict(X_train)
    y_pred_test  = model.predict(X_test)

    train_r2 = r2_score(y_train, y_pred_train)
    print(f"\n  Training R²: {train_r2:.4f}")
    compute_metrics(y_test, y_pred_test, label="Ridge – Test Set")

    return model, y_pred_test


def train_lasso(X_train, y_train, X_test, y_test, alpha=0.1):
    """Lasso Regression (L1 regularisation)"""
    print("\n" + "=" * 80)
    print(f"STEP 5C: TRAINING LASSO REGRESSION  (alpha={alpha})")
    print("=" * 80)

    model = Pipeline([
        ('scaler', StandardScaler()),
        ('lasso',  Lasso(alpha=alpha, max_iter=10000))
    ])
    model.fit(X_train, y_train)

    y_pred_train = model.predict(X_train)
    y_pred_test  = model.predict(X_test)

    train_r2 = r2_score(y_train, y_pred_train)
    print(f"\n  Training R²: {train_r2:.4f}")
    compute_metrics(y_test, y_pred_test, label="Lasso – Test Set")

    # Lasso naturally zeroes out features → report sparsity
    n_nonzero = np.sum(model.named_steps['lasso'].coef_ != 0)
    print(f"\n  Lasso non-zero coefficients: {n_nonzero} / {X_train.shape[1]}")

    return model, y_pred_test


# ============================================================================
# 6. FEATURE IMPORTANCE ANALYSIS  (coefficients for linear models)
# ============================================================================

def plot_feature_importance_linear(model, feature_names, model_name='Model', top_n=20):
    """
    Plot feature importance for linear models using |standardised coefficient|.
    """
    coef = model.named_steps[list(model.named_steps.keys())[-1]].coef_
    importance = np.abs(coef)
    indices = np.argsort(importance)[::-1][:top_n]

    plt.figure(figsize=(12, 8))
    colors = plt.cm.viridis(np.linspace(0.3, 0.9, len(indices)))
    plt.barh(range(len(indices)), importance[indices], color=colors, alpha=0.8)
    plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
    plt.xlabel('|Standardised Coefficient|', fontsize=12, fontweight='bold')
    plt.ylabel('Features', fontsize=12, fontweight='bold')
    plt.title(f'{model_name} – Top {top_n} Feature Importances',
              fontsize=14, fontweight='bold')
    plt.gca().invert_yaxis()
    plt.grid(True, alpha=0.3, axis='x')
    plt.tight_layout()

    fname = f'{model_name.lower().replace(" ", "_")}_feature_importance.png'
    plt.savefig(fname, dpi=300, bbox_inches='tight')
    print(f"✓ Saved: {fname}")
    plt.show()

    print(f"\nTop 10 features for {model_name}:")
    for i, idx in enumerate(indices[:10], 1):
        sign = '+' if coef[idx] >= 0 else '-'
        print(f"  {i:2d}. {feature_names[idx]:30s}: {sign}{importance[idx]:.4f}")

    return importance, indices


# ============================================================================
# 7. COMPREHENSIVE VISUALISATIONS
# ============================================================================

def plot_comprehensive_results(y_test, y_pred_ols, y_pred_ridge, y_pred_lasso):
    """
    Comprehensive diagnostic plots for all three linear models.
    """
    print("\n" + "=" * 80)
    print("STEP 6: GENERATING VISUALISATIONS")
    print("=" * 80)

    sns.set_style("whitegrid")
    models = {
        'OLS':   (y_pred_ols,   'royalblue'),
        'Ridge': (y_pred_ridge, 'darkorange'),
        'Lasso': (y_pred_lasso, 'seagreen'),
    }

    fig = plt.figure(figsize=(22, 16))
    gs  = fig.add_gridspec(4, 3, hspace=0.35, wspace=0.30)

    # Row 0 – Actual vs Predicted
    for col_idx, (name, (y_pred, color)) in enumerate(models.items()):
        ax = fig.add_subplot(gs[0, col_idx])
        ax.scatter(y_test, y_pred, alpha=0.4, s=15, c=color, edgecolors='none')
        lim = [min(y_test.min(), y_pred.min()), max(y_test.max(), y_pred.max())]
        ax.plot(lim, lim, 'r--', lw=1.5, label='1:1 line')
        ax.set_xlabel('Actual NO₂ (µg/m³)',    fontsize=10, fontweight='bold')
        ax.set_ylabel('Predicted NO₂ (µg/m³)', fontsize=10, fontweight='bold')
        r2 = r2_score(y_test, y_pred)
        ax.set_title(f'{name}: Actual vs Predicted\nR²={r2:.4f}', fontsize=11, fontweight='bold')
        ax.legend(fontsize=8)
        ax.grid(True, alpha=0.3)

    # Row 1 – Residual plots
    for col_idx, (name, (y_pred, color)) in enumerate(models.items()):
        ax = fig.add_subplot(gs[1, col_idx])
        residuals = y_test - y_pred
        ax.scatter(y_pred, residuals, alpha=0.35, s=15, c=color, edgecolors='none')
        ax.axhline(0, color='r', ls='--', lw=1.5)
        ax.set_xlabel('Predicted NO₂ (µg/m³)', fontsize=10, fontweight='bold')
        ax.set_ylabel('Residuals (µg/m³)',       fontsize=10, fontweight='bold')
        ax.set_title(f'{name}: Residuals',       fontsize=11, fontweight='bold')
        ax.grid(True, alpha=0.3)

    # Row 2 – Residual distribution
    ax_dist = fig.add_subplot(gs[2, :2])
    for name, (y_pred, color) in models.items():
        residuals = y_test - y_pred
        ax_dist.hist(residuals, bins=60, alpha=0.55, label=name,
                     color=color, edgecolor='white')
    ax_dist.axvline(0, color='red', ls='--', lw=1.5)
    ax_dist.set_xlabel('Residuals (µg/m³)', fontsize=11, fontweight='bold')
    ax_dist.set_ylabel('Frequency',          fontsize=11, fontweight='bold')
    ax_dist.set_title('Residual Distribution – All Models', fontsize=12, fontweight='bold')
    ax_dist.legend()
    ax_dist.grid(True, alpha=0.3, axis='y')

    # Row 2 col 2 – Metric bar chart
    ax_bar = fig.add_subplot(gs[2, 2])
    metric_names = ['R²', 'RMSE/50', 'MAE/50']
    x = np.arange(len(models))
    width = 0.25
    r2s   = [r2_score(y_test, y_pred) for _, (y_pred, _) in models.items()]
    rmses = [np.sqrt(mean_squared_error(y_test, y_pred)) / 50 for _, (y_pred, _) in models.items()]
    maes  = [mean_absolute_error(y_test, y_pred) / 50 for _, (y_pred, _) in models.items()]
    ax_bar.bar(x - width, r2s,   width, label='R²',      alpha=0.8, color='steelblue')
    ax_bar.bar(x,         rmses, width, label='RMSE/50',  alpha=0.8, color='tomato')
    ax_bar.bar(x + width, maes,  width, label='MAE/50',   alpha=0.8, color='mediumpurple')
    ax_bar.set_xticks(x)
    ax_bar.set_xticklabels(list(models.keys()))
    ax_bar.set_ylabel('Score', fontsize=11, fontweight='bold')
    ax_bar.set_title('Model Performance Comparison', fontsize=12, fontweight='bold')
    ax_bar.legend(fontsize=8)
    ax_bar.grid(True, alpha=0.3, axis='y')

    # Row 3 – MAE by concentration range
    bins = [0, 20, 40, 60, 80, 100, float(y_test.max())]
    bin_labels_str = []
    y_test_binned  = pd.cut(y_test, bins=bins)
    cats = y_test_binned.cat.categories

    for col_idx, (name, (y_pred, color)) in enumerate(models.items()):
        ax = fig.add_subplot(gs[3, col_idx])
        residuals = y_test - y_pred
        mae_by_bin = [np.abs(residuals[y_test_binned == b]).mean() for b in cats]
        ax.bar(range(len(mae_by_bin)), mae_by_bin, alpha=0.75, color=color)
        ax.set_xticks(range(len(cats)))
        ax.set_xticklabels([f'{int(b.left)}-{int(b.right)}' for b in cats], rotation=45)
        ax.set_xlabel('NO₂ Range (µg/m³)', fontsize=10, fontweight='bold')
        ax.set_ylabel('MAE',               fontsize=10, fontweight='bold')
        ax.set_title(f'{name}: MAE by Concentration Range', fontsize=11, fontweight='bold')
        ax.grid(True, alpha=0.3, axis='y')

    plt.suptitle('Air Quality NO₂ Downscaling – Linear Model Evaluation',
                 fontsize=16, fontweight='bold', y=1.01)

    plt.savefig('model_evaluation_comprehensive.png', dpi=300, bbox_inches='tight')
    print("✓ Saved: model_evaluation_comprehensive.png")
    plt.show()


def plot_metrics_summary_table(y_test, preds_dict):
    """
    Print and plot a full metrics table for all models,
    including MBE, NMB, Pearson r, MAPE, IOA.
    """
    print("\n" + "=" * 80)
    print("COMPREHENSIVE METRICS SUMMARY")
    print("=" * 80)

    rows = []
    for name, y_pred in preds_dict.items():
        m = compute_metrics(y_test, y_pred)
        m['Model'] = name
        rows.append(m)

    summary_df = pd.DataFrame(rows).set_index('Model')
    summary_df = summary_df[['R2','RMSE','MAE','MBE','NMB','Pearson_r','MAPE','IOA']]

    print("\n" + summary_df.round(4).to_string())

    # Heatmap of normalised metrics
    fig, ax = plt.subplots(figsize=(12, 3))
    norm_df = summary_df.copy()

    # For RMSE / MAE / MBE / MAPE: lower = better → invert for heatmap colouring
    for col in ['RMSE', 'MAE', 'MAPE']:
        norm_df[col] = 1 / (norm_df[col] + 1e-9)
    for col in ['MBE']:
        norm_df[col] = 1 / (np.abs(norm_df[col]) + 1e-9)
    for col in ['NMB']:
        norm_df[col] = 1 / (np.abs(norm_df[col]) + 1e-9)

    sns.heatmap(
        norm_df.T, annot=summary_df.round(3).T, fmt='',
        cmap='YlGn', ax=ax, linewidths=0.5,
        cbar_kws={'label': 'Higher = better (normalised)'}
    )
    ax.set_title('Metrics Heatmap – All Linear Models', fontsize=13, fontweight='bold')
    plt.tight_layout()
    plt.savefig('metrics_heatmap.png', dpi=300, bbox_inches='tight')
    print("\n✓ Saved: metrics_heatmap.png")
    plt.show()

    return summary_df


# ============================================================================
# 8. SAVE MODELS
# ============================================================================

def save_models(ols_model, ridge_model, lasso_model, test_station_info):
    """
    Save trained models to Google Drive
    """
    import pickle, os

    print("\n" + "=" * 80)
    print("STEP 7: SAVING MODELS TO GOOGLE DRIVE")
    print("=" * 80)

    save_dir = '/content/drive/MyDrive/MAJOR_PROJECT/trained_models'
    os.makedirs(save_dir, exist_ok=True)

    for name, mdl in [('ols', ols_model), ('ridge', ridge_model), ('lasso', lasso_model)]:
        path = f'{save_dir}/{name}_no2_model.pkl'
        with open(path, 'wb') as f:
            pickle.dump(mdl, f)
        print(f"✓ Saved: {path}")

    import json
    json_path = f'{save_dir}/test_station_info.json'
    with open(json_path, 'w') as f:
        json.dump(test_station_info, f, indent=2)
    print(f"✓ Saved: {json_path}")

    print("\n✓ All models saved to Google Drive!")
    print(f"\n  Location: {save_dir}")


# ============================================================================
# 9. MAIN EXECUTION PIPELINE
# ============================================================================

def main(filepath):
    print("\n")
    print("╔" + "=" * 78 + "╗")
    print("║" + " " * 78 + "║")
    print("║" + "  AIR QUALITY NO₂ DOWNSCALING MODEL – DELHI".center(78) + "║")
    print("║" + "  OLS | RIDGE | LASSO   ·   No Lag Features".center(78) + "║")
    print("║" + "  TEMPORAL + SPATIAL VALIDATION".center(78) + "║")
    print("║" + " " * 78 + "║")
    print("╚" + "=" * 78 + "╝")
    print(f"\nStart time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

    # ── Pipeline ─────────────────────────────────────────────────────────────
    df = load_and_preprocess_data(filepath)
    df = handle_missing_values(df)          # ML-based gap filling
    df = create_features(df)               # spatial_lag_no2 included; lags excluded

    (X_train, X_test, y_train, y_test,
     feature_cols, test_station_info,
     df_test_meta) = prepare_train_test_split(df)

    # ── Train models ─────────────────────────────────────────────────────────
    ols_model,   y_pred_ols   = train_ols(X_train, y_train, X_test, y_test)
    ridge_model, y_pred_ridge = train_ridge(X_train, y_train, X_test, y_test)
    lasso_model, y_pred_lasso = train_lasso(X_train, y_train, X_test, y_test)

    # ── Spatial & Temporal R² (uses metadata from the test split) ─────────────
    print("\n" + "=" * 80)
    print("SPATIAL & TEMPORAL R²")
    print("=" * 80)
    for name, y_pred in [('OLS', y_pred_ols), ('Ridge', y_pred_ridge), ('Lasso', y_pred_lasso)]:
        print(f"\n  ── {name} ──")
        compute_spatial_r2( df_test_meta.reset_index(drop=True), y_pred, station_col='station')
        compute_temporal_r2(df_test_meta.reset_index(drop=True), y_pred, date_col='date')

    # ── Visualisations ───────────────────────────────────────────────────────
    plot_comprehensive_results(y_test, y_pred_ols, y_pred_ridge, y_pred_lasso)

    preds_dict = {'OLS': y_pred_ols, 'Ridge': y_pred_ridge, 'Lasso': y_pred_lasso}
    summary_df = plot_metrics_summary_table(y_test, preds_dict)

    # ── Feature importance for each model ────────────────────────────────────
    for name, mdl in [('OLS', ols_model), ('Ridge', ridge_model), ('Lasso', lasso_model)]:
        plot_feature_importance_linear(mdl, feature_cols, model_name=name)

    # ── Save ─────────────────────────────────────────────────────────────────
    save_models(ols_model, ridge_model, lasso_model, test_station_info)

    # ── Final summary ─────────────────────────────────────────────────────────
    print("\n" + "=" * 80)
    print("PIPELINE COMPLETED SUCCESSFULLY! 🎉")
    print("=" * 80)
    print(f"End time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print("\n✓ Models:       OLS | Ridge | Lasso")
    print("✓ Gap filling:  ML-based (Ridge auxiliary model – no mean imputation)")
    print("✓ Spatial lag:  spatial_lag_no2 feature added")
    print("✓ Lag features: REMOVED")
    print("✓ Metrics:      R², RMSE, MAE, MBE, NMB, Pearson r, MAPE, IOA,")
    print("                Spatial R², Temporal R²")
    print("✓ Visualisations and models saved")

    best_model = max(preds_dict, key=lambda n: r2_score(y_test, preds_dict[n]))
    print(f"\n  → Best model by R²: {best_model}")

    print("\n📍 Test Stations (never seen during training):")
    for s in test_station_info['test_stations']:
        print(f"   • {s}")

    return ols_model, ridge_model, lasso_model, feature_cols, \
           X_train, X_test, y_train, y_test, test_station_info


# ============================================================================
# 10. USAGE
# ============================================================================

"""
HOW TO USE IN GOOGLE COLAB:
============================

1. Install required packages (run once):
   # !pip install scikit-learn pandas numpy matplotlib seaborn scipy

2. Mount drive and run:
   filepath = '/content/drive/MyDrive/MAJOR_PROJECT/MASTERDATASET_39.csv'
   ols, ridge, lasso, features, X_train, X_test, y_train, y_test, info = main(filepath)

3. Make predictions on new data:
   new_predictions = ridge.predict(X_new[features])

EXPECTED OUTPUTS:
=================
- model_evaluation_comprehensive.png  (actual vs predicted, residuals, MAE by range)
- metrics_heatmap.png                 (all 8 metrics across 3 models)
- ols_feature_importance.png
- ridge_feature_importance.png
- lasso_feature_importance.png
- ols_no2_model.pkl
- ridge_no2_model.pkl
- lasso_no2_model.pkl
- test_station_info.json

KEY CHANGES FROM PREVIOUS VERSION:
====================================
✓ Models:       XGBoost + Random Forest  → OLS + Ridge + Lasso
✓ Gap filling:  Mean imputation          → ML-based reconstruction (Ridge auxiliary)
✓ Features:     Lag / MA features        → REMOVED
✓ Features:     spatial_lag_no2          → ADDED (mean NO2 of ≤11 km neighbours, same day)
✓ Metrics:      R², RMSE, MAE           → + MBE, NMB, Pearson r, MAPE, IOA,
                                            Spatial R², Temporal R²
"""

if __name__ == "__main__":
    filepath = '/content/drive/MyDrive/MAJOR_PROJECT/MASTERDATASET_39.csv'
    ols_model, ridge_model, lasso_model, features, \
    X_train, X_test, y_train, y_test, test_station_info = main(filepath)


# ============================================================================
# FISHNET PREDICTION PIPELINE  (unchanged structure; updated for linear models)
# ============================================================================

import pandas as pd
import numpy as np
import pickle

FISHNET_PATH = "/content/drive/MyDrive/MAJOR_PROJECT/Delhi_500m_ML_Ready_2024.csv"
MODEL_PATH   = "/content/drive/MyDrive/MAJOR_PROJECT/trained_models/ridge_no2_model.pkl"

df = pd.read_csv(FISHNET_PATH)
df['date'] = pd.to_datetime(df['date'])

with open(MODEL_PATH, "rb") as f:
    model = pickle.load(f)

EXPECTED_FEATURES = list(model.feature_names_in_)
print("Model expects:", len(EXPECTED_FEATURES), "features")

# ── Rename if needed ──────────────────────────────────────────────────────────
df = df.rename(columns={'temperature_C': 'temperature_2m_C'})

# ── Temporal features ─────────────────────────────────────────────────────────
df['year']           = df['date'].dt.year
df['month']          = df['date'].dt.month
df['day']            = df['date'].dt.day
df['day_of_year']    = df['date'].dt.dayofyear
df['day_of_week']    = df['date'].dt.weekday
df['is_weekend']     = (df['day_of_week'] >= 5).astype(int)
df['season_numeric'] = df['month'].map({12:1,1:1,2:1,3:2,4:2,5:2,6:3,7:3,8:3,9:4,10:4,11:4})
df['is_critical_winter'] = df['month'].isin([12,1,2]).astype(int)

# ── Meteorological features ───────────────────────────────────────────────────
df['wind_direction']   = (np.degrees(np.arctan2(df['v10'], df['u10'])) + 360) % 360
df['ventilation_coef'] = df['BLH'] * df['wind_speed']
df['stability_index']  = df['BLH'] / (df['wind_speed'] + 0.1)
df['is_cold'] = (df['temperature_2m_C'] < 15).astype(int)
df['is_hot']  = (df['temperature_2m_C'] > 30).astype(int)

# ── Emission proxies ──────────────────────────────────────────────────────────
df['urban_intensity']     = df['population_density'] * df['night_light']
df['urban_intensity_log'] = np.log1p(df['urban_intensity'])

lat0, lon0 = 28.6139, 77.2090
df['dist_from_center'] = np.sqrt(
    (df['lat'] - lat0)**2 + (df['lon'] - lon0)**2
) * 111

# ── ML-based gap filling (fishnet) ────────────────────────────────────────────
df['satellite_missing_flag'] = df['tropospheric_no2'].isna().astype(int)

# Auxiliary Ridge for fishnet gap filling
proxy_cols_fn = [c for c in df.columns
                 if c not in ['cell_id','date','tropospheric_no2','satellite_missing_flag']
                 and df[c].dtype in [np.float64, np.float32, np.int64, np.int32]]

obs_mask_fn  = df['satellite_missing_flag'] == 0
gap_mask_fn  = df['satellite_missing_flag'] == 1

if gap_mask_fn.sum() > 0:
    # Keep only columns clean in BOTH obs and gap rows; imputer handles stragglers
    valid_fn = [
        c for c in proxy_cols_fn
        if df.loc[obs_mask_fn, c].isnull().sum() == 0
        and df.loc[gap_mask_fn, c].isnull().sum() == 0
    ]
    if not valid_fn:
        valid_fn = proxy_cols_fn   # fallback: let imputer clean everything

    aux_fn = Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler',  StandardScaler()),
        ('ridge',   Ridge(alpha=1.0))
    ])
    aux_fn.fit(df.loc[obs_mask_fn, valid_fn].copy(),
               df.loc[obs_mask_fn, 'tropospheric_no2'])
    df.loc[gap_mask_fn, 'tropospheric_no2'] = np.clip(
        aux_fn.predict(df.loc[gap_mask_fn, valid_fn].copy()), 0, None
    )
    print(f"✅ ML gap-filled {gap_mask_fn.sum():,} missing satellite cells")

# ── Spatial neighbour feature (fishnet) ───────────────────────────────────────
print("Computing spatial_lag_no2 for fishnet …  (may take a moment)")
df = df.sort_values(['date', 'cell_id']).reset_index(drop=True)

cell_coords = df[['cell_id','lat','lon']].drop_duplicates().set_index('cell_id')
daily_cell  = df.groupby(['date','cell_id'])['tropospheric_no2'].mean()

spatial_lag_fn = []
for _, row in df.iterrows():
    dist = np.sqrt(
        (cell_coords['lat'] - row['lat'])**2 +
        (cell_coords['lon'] - row['lon'])**2
    )
    nbrs = dist[(dist <= 0.005) & (dist.index != row['cell_id'])].index.tolist()
    if nbrs:
        vals = [daily_cell[(row['date'], n)] for n in nbrs
                if (row['date'], n) in daily_cell.index]
        spatial_lag_fn.append(np.mean(vals) if vals else np.nan)
    else:
        spatial_lag_fn.append(np.nan)

df['spatial_lag_no2'] = spatial_lag_fn
df['spatial_lag_no2'] = df.groupby('cell_id')['spatial_lag_no2'].transform(
    lambda x: x.fillna(x.mean())
)
df['spatial_lag_no2'] = df['spatial_lag_no2'].fillna(df['tropospheric_no2'])

# ── Interaction features ──────────────────────────────────────────────────────
df['satellite_stability']    = df['tropospheric_no2'] * df['stability_index']
df['cloud_temp_interaction'] = df['total_cloud_cover'] * (1 / (df['temperature_2m_C'] + 1))

# ── Check & predict ───────────────────────────────────────────────────────────
missing_feats = set(EXPECTED_FEATURES) - set(df.columns)
print("Missing features:", missing_feats)

X_fishnet = df[EXPECTED_FEATURES].fillna(df[EXPECTED_FEATURES].mean())
df['no2_pred_ugm3'] = model.predict(X_fishnet)

print(df[['lat','lon','no2_pred_ugm3','date']].head())

# ── Export GeoTIFF ────────────────────────────────────────────────────────────
import os, rasterio
from rasterio.transform import from_origin
import geopandas as gpd

gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.lon, df.lat), crs="EPSG:4326"
).to_crs("EPSG:32643")

PIXEL_SIZE = 500
minx, miny, maxx, maxy = gdf.total_bounds
width  = int((maxx - minx) / PIXEL_SIZE)
height = int((maxy - miny) / PIXEL_SIZE)
transform = from_origin(minx, maxy, PIXEL_SIZE, PIXEL_SIZE)

# Daily GeoTIFFs
OUT_DIR = "/content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily"
os.makedirs(OUT_DIR, exist_ok=True)

for date, day_df in gdf.groupby('date'):
    raster = np.full((height, width), np.nan, dtype=np.float32)
    for _, row in day_df.iterrows():
        c  = int((row.geometry.x - minx) / PIXEL_SIZE)
        ri = int((maxy - row.geometry.y) / PIXEL_SIZE)
        if 0 <= ri < height and 0 <= c < width:
            raster[ri, c] = row.no2_pred_ugm3

    out_path = f"{OUT_DIR}/NO2_500m_{date.strftime('%Y%m%d')}.tif"
    with rasterio.open(out_path, "w", driver="GTiff",
                       height=height, width=width,
                       count=1, dtype="float32",
                       crs="EPSG:32643", transform=transform,
                       nodata=np.nan) as dst:
        dst.write(raster, 1)
    print(f"✅ Exported {out_path}")

# Monthly GeoTIFFs
OUT_DIR_MONTH = "/content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly"
os.makedirs(OUT_DIR_MONTH, exist_ok=True)

gdf['month_period'] = gdf['date'].dt.to_period('M')
for month, mdf in gdf.groupby('month_period'):
    raster = np.full((height, width), np.nan, dtype=np.float32)
    mean_df  = mdf.groupby(['lon','lat'])['no2_pred_ugm3'].mean().reset_index()
    mean_gdf = gpd.GeoDataFrame(
        mean_df, geometry=gpd.points_from_xy(mean_df.lon, mean_df.lat), crs="EPSG:4326"
    ).to_crs("EPSG:32643")

    for _, row in mean_gdf.iterrows():
        c  = int((row.geometry.x - minx) / PIXEL_SIZE)
        ri = int((maxy - row.geometry.y) / PIXEL_SIZE)
        if 0 <= ri < height and 0 <= c < width:
            raster[ri, c] = row.no2_pred_ugm3

    out_path = f"{OUT_DIR_MONTH}/NO2_500m_{month}.tif"
    with rasterio.open(out_path, "w", driver="GTiff",
                       height=height, width=width,
                       count=1, dtype="float32",
                       crs="EPSG:32643", transform=transform,
                       nodata=np.nan) as dst:
        dst.write(raster, 1)
    print(f"📅 Exported monthly {out_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✓ All libraries imported successfully
#
#
# ╔==============================================================================╗
# ║                                                                              ║
# ║                   AIR QUALITY NO₂ DOWNSCALING MODEL – DELHI                  ║
# ║                   OLS | RIDGE | LASSO   ·   No Lag Features                  ║
# ║                         TEMPORAL + SPATIAL VALIDATION                        ║
# ║                                                                              ║
# ╚==============================================================================╝
#
# Start time: 2026-02-17 09:03:58
#
# ================================================================================
# STEP 1: LOADING DATA
# ================================================================================
# ✓ Data loaded successfully
#   - Rows: 14,274
#   - Columns: 15
#   - Stations: 39
# ✓ Date converted to datetime
#   - Date range: 2024-01-01 00:00:00 to 2024-12-31 00:00:00
#   - Total days: 365
#
# ✓ Sample of your data:
#        station       lat        lon       date  groundtruth_no2  tropospheric_no2  population_density  night_light       u10       v10  wind_speed  temperature_2m_C  surface_pressure_hPa         BLH  total_cloud_cover
# 0  NSIT DWARKA  28.60909  77.032541 2024-01-01        33.085000          0.000171         22871.21582        28.02  0.735884 -1.113805    1.334948         10.495179            993.666273  208.861001           0.216734
# 1  NSIT DWARKA  28.60909  77.032541 2024-01-02        20.070000          0.000226         22871.21582        28.02  0.471414 -1.146077    1.239244          9.833268            993.054412  169.142094           0.377602
# 2  NSIT DWARKA  28.60909  77.032541 2024-01-03        60.624167          0.000259         22871.21582        28.02  0.696646 -0.827309    1.081552         10.355922            992.756494  216.545671           0.470620
#
# --------------------------------------------------------------------------------
# DATA QUALITY CHECK
# --------------------------------------------------------------------------------
# Missing values found:
#   - groundtruth_no2: 363 (2.5%)
#   - tropospheric_no2: 3,863 (27.1%)
#   - BLH: 1 (0.0%)
#   - total_cloud_cover: 1 (0.0%)
#
# ================================================================================
# STEP 2: HANDLING MISSING VALUES  (ML-based gap filling)
# ================================================================================
# ✓ Removed 363 rows with missing groundtruth_no2
#
# ✓ 3,736 rows have missing tropospheric_no2 (cloudy days)
#   → Training auxiliary Ridge model to reconstruct gaps …
#   ✓ Auxiliary model train R² = 0.259
#   ✓ Replaced 3,736 missing satellite values with ML predictions
#
# ⚠ Warning: 2 missing values in other features
#   - Filling with column means (last resort) …
#   ✓ Done
#
# ✓ Final dataset: 13,911 rows ready for modeling
#
# ================================================================================
# STEP 3: FEATURE ENGINEERING
# ================================================================================
#
# 1. Creating temporal features …
#    ✓ Added 8 temporal features
#
# 2. Creating meteorological features …
#    ✓ Added 7 meteorological features
#
# 3. Creating emission proxy features …
#    ✓ Added 2 emission proxy features
#
# 4. Creating spatial features …
#    ✓ Added 1 distance feature
#
# 5. Creating spatial neighbor feature (spatio-temporal) …
#    Computing mean tropospheric_no2 of adjacent stations on the same day …
#    ✓ Added 1 spatial_lag_no2 feature  (true spatio-temporal signal)
#
# 6. Creating interaction features …
#    ✓ Added 2 interaction features
#
# --------------------------------------------------------------------------------
# ✓ FEATURE ENGINEERING COMPLETE
#   - Started with: 16 columns
#   - Created: 21 new features
#   - Total features: 37 columns
#   ✗ Lag / moving-average features: NOT added (removed as requested)
#   ✓ spatial_lag_no2: ADDED (true spatio-temporal feature)
# --------------------------------------------------------------------------------
#
# ================================================================================
# STEP 4: PREPARING TRAIN-TEST SPLIT
# ================================================================================
#
# ⚠️  ADVANCED VALIDATION STRATEGY:
#    1. TEMPORAL SPLIT: Train on Mar-Nov, Test on Dec-Feb (winter)
#    2. SPATIAL SPLIT : 5 stations held out for testing
# ================================================================================
#
# ✓ Selected 32 features for modeling
# Feature categories:
#   - Temporal:          8
#   - Meteorological:    10
#   - Spatial/Emission:  9
#   - Satellite:         3
#   - Lag/Moving Avg:    0  (removed as requested)
#
# --------------------------------------------------------------------------------
# SPATIAL SPLIT: Selecting test-only stations
# ✓ Total stations: 39
# ✓ Stations reserved for TESTING ONLY:
#    1. SONIA VIHAR
#    2. WAZIRPUR
#    3. BAWANA
#    4. JAHANGIRPURI
#    5. ROHINI
#
# --------------------------------------------------------------------------------
# TEMPORAL SPLIT: Train on Mar-Nov, Test on Dec-Feb
# ✓ Training samples (Mar-Nov):            9,071
# ✓ Temporal test (Dec-Feb, train sta.):   3,017
# ✓ Spatial test  (all months, 5 sta.):    1,823
# ✓ Total test samples:                    4,840
#
# ✓ TRAINING SET: 9,071 samples | NO2 mean=40.41
# ✓ TESTING  SET: 4,840  samples | NO2 mean=47.75
#
# ================================================================================
# ✓ DATA SPLIT COMPLETE - NO DATA LEAKAGE GUARANTEED
# ================================================================================
#
# ================================================================================
# STEP 5A: TRAINING OLS LINEAR REGRESSION
# ================================================================================
#
#   Training R²: 0.1351
#
# ────────────────────────────────────────────────────────────
#   METRICS: OLS – Test Set
# ────────────────────────────────────────────────────────────
#   R²          : 0.0315
#   RMSE        : 33.2991 µg/m³
#   MAE         : 22.6654 µg/m³
#   MBE         : -4.1253 µg/m³  (+ = over-predict)
#   NMB         : -0.0864         (fraction)
#   Pearson r   : 0.2840  (p=1.81e-90)
#   MAPE        : 81.80 %
#   IOA         : 0.4788
#   ⚠ FAIR
#
# ================================================================================
# STEP 5B: TRAINING RIDGE REGRESSION  (alpha=1.0)
# ================================================================================
#
#   Training R²: 0.1345
#
# ────────────────────────────────────────────────────────────
#   METRICS: Ridge – Test Set
# ────────────────────────────────────────────────────────────
#   R²          : 0.0363
#   RMSE        : 33.2175 µg/m³
#   MAE         : 23.1119 µg/m³
#   MBE         : -0.1157 µg/m³  (+ = over-predict)
#   NMB         : -0.0024         (fraction)
#   Pearson r   : 0.2878  (p=6.15e-93)
#   MAPE        : 90.85 %
#   IOA         : 0.4864
#
# ================================================================================
# STEP 5C: TRAINING LASSO REGRESSION  (alpha=0.1)
# ================================================================================
#
#   Training R²: 0.1307
#
# ────────────────────────────────────────────────────────────
#   METRICS: Lasso – Test Set
# ────────────────────────────────────────────────────────────
#   R²          : 0.0965
#   RMSE        : 32.1628 µg/m³
#   MAE         : 22.0927 µg/m³
#   MBE         : -1.0232 µg/m³  (+ = over-predict)
#   NMB         : -0.0214         (fraction)
#   Pearson r   : 0.3163  (p=6.93e-113)
#   MAPE        : 88.66 %
#   IOA         : 0.4282
#
#   Lasso non-zero coefficients: 24 / 32
#
# ================================================================================
# SPATIAL & TEMPORAL R²
# ================================================================================
#
#   ── OLS ──
#
#   Spatial R²  : 0.1515  (n_stations=39)
#   Spatial r   : 0.4363
#   Temporal R² : 0.1158  (n_days=366)
#   Temporal r  : 0.4389
#
#   ── Ridge ──
#
#   Spatial R²  : 0.1716  (n_stations=39)
#   Spatial r   : 0.4206
#   Temporal R² : 0.1152  (n_days=366)
#   Temporal r  : 0.4458
#
#   ── Lasso ──
#
#   Spatial R²  : 0.1723  (n_stations=39)
#   Spatial r   : 0.4209
#   Temporal R² : 0.2135  (n_days=366)
#   Temporal r  : 0.4778
#
# ================================================================================
# STEP 6: GENERATING VISUALISATIONS
# ================================================================================
# ✓ Saved: model_evaluation_comprehensive.png
# ================================================================================
# COMPREHENSIVE METRICS SUMMARY
# ================================================================================
#
#            R2     RMSE      MAE     MBE     NMB  Pearson_r     MAPE     IOA
# Model
# OLS    0.0315  33.2991  22.6654 -4.1253 -0.0864     0.2840  81.8012  0.4788
# Ridge  0.0363  33.2175  23.1119 -0.1157 -0.0024     0.2878  90.8475  0.4864
# Lasso  0.0965  32.1628  22.0927 -1.0232 -0.0214     0.3163  88.6648  0.4282
#
# ✓ Saved: metrics_heatmap.png
# ✓ Saved: ols_feature_importance.png
# Top 10 features for OLS:
#    1. month                         : +343.1277
#    2. day_of_year                   : -339.0689
#    3. day                           : +37.3086
#    4. urban_intensity               : +16.0755
#    5. night_light                   : -10.8244
#    6. BLH                           : +6.6474
#    7. population_density            : -6.1974
#    8. temperature_2m_C              : -4.8063
#    9. dist_from_center              : -3.3399
#   10. urban_intensity_log           : +2.8859
# ✓ Saved: ridge_feature_importance.png
# Top 10 features for Ridge:
#    1. urban_intensity               : +16.3851
#    2. month                         : +11.4234
#    3. night_light                   : -11.0312
#    4. population_density            : -6.4174
#    5. BLH                           : +5.6435
#    6. temperature_2m_C              : -5.1431
#    7. season_numeric                : -3.8798
#    8. day_of_year                   : -3.4733
#    9. dist_from_center              : -3.3107
#   10. urban_intensity_log           : +3.0335
# ✓ Saved: lasso_feature_importance.png
# Top 10 features for Lasso:
#    1. urban_intensity               : +10.2068
#    2. night_light                   : -5.5429
#    3. month                         : +4.6245
#    4. BLH                           : +3.9267
#    5. temperature_2m_C              : -3.8402
#    6. dist_from_center              : -3.1291
#    7. wind_speed                    : -2.5570
#    8. surface_pressure_hPa          : +1.8211
#    9. v10                           : -1.7064
#   10. lon                           : +1.6348
#
# ================================================================================
# STEP 7: SAVING MODELS TO GOOGLE DRIVE
# ================================================================================
# ✓ Saved: /content/drive/MyDrive/MAJOR_PROJECT/trained_models/ols_no2_model.pkl
# ✓ Saved: /content/drive/MyDrive/MAJOR_PROJECT/trained_models/ridge_no2_model.pkl
# ✓ Saved: /content/drive/MyDrive/MAJOR_PROJECT/trained_models/lasso_no2_model.pkl
# ✓ Saved: /content/drive/MyDrive/MAJOR_PROJECT/trained_models/test_station_info.json
#
# ✓ All models saved to Google Drive!
#
#   Location: /content/drive/MyDrive/MAJOR_PROJECT/trained_models
#
# ================================================================================
# PIPELINE COMPLETED SUCCESSFULLY! 🎉
# ================================================================================
# End time: 2026-02-17 09:04:34
#
# ✓ Models:       OLS | Ridge | Lasso
# ✓ Gap filling:  ML-based (Ridge auxiliary model – no mean imputation)
# ✓ Spatial lag:  spatial_lag_no2 feature added
# ✓ Lag features: REMOVED
# ✓ Metrics:      R², RMSE, MAE, MBE, NMB, Pearson r, MAPE, IOA,
#                 Spatial R², Temporal R²
# ✓ Visualisations and models saved
#
#   → Best model by R²: Lasso
#
# 📍 Test Stations (never seen during training):
#    • SONIA VIHAR
#    • WAZIRPUR
#    • BAWANA
#    • JAHANGIRPURI
#    • ROHINI
# Model expects: 32 features
# Computing spatial_lag_no2 for fishnet …  (may take a moment)
# Missing features: set()
#          lat        lon  no2_pred_ugm3       date
# 0  28.561197  76.837604      12.451045 2024-01-01
# 1  28.565708  76.837682      12.192584 2024-01-01
# 2  28.570219  76.837761      10.912462 2024-01-01
# 3  28.574730  76.837839      10.401977 2024-01-01
# 4  28.579241  76.837917      10.246018 2024-01-01
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240101.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240102.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240103.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240104.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240105.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240106.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240107.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240108.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240109.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240110.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240111.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240112.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240113.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240114.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240115.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240116.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240117.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240118.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240119.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240120.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240121.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240122.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240123.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240124.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240125.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240126.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240127.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240128.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240129.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240130.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240131.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240201.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240202.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240203.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240204.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240205.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240206.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240207.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240208.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240209.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240210.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240211.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240212.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240213.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240214.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240215.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240216.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240217.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240218.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240219.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240220.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240221.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240222.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240223.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240224.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240225.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240226.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240227.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240228.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240229.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240301.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240302.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240303.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240304.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240305.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240306.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240307.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240308.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240309.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240310.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240311.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240312.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240313.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240314.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240315.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240316.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240317.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240318.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240319.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240320.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240321.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240322.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240323.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240324.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240325.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240326.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240327.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240328.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240329.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240330.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240331.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240401.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240402.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240403.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240404.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240405.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240406.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240407.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240408.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240409.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240410.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240411.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240412.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240413.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240414.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240415.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240416.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240417.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240418.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240419.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240420.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240421.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240422.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240423.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240424.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240425.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240426.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240427.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240428.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240429.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240430.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240501.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240502.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240503.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240504.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240505.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240506.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240507.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240508.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240509.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240510.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240511.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240512.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240513.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240514.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240515.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240516.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240517.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240518.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240519.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240520.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240521.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240522.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240523.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240524.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240525.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240526.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240527.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240528.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240529.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240530.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240531.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240601.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240602.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240603.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240604.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240605.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240606.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240607.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240608.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240609.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240610.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240611.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240612.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240613.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240614.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240615.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240616.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240617.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240618.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240619.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240620.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240621.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240622.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240623.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240624.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240625.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240626.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240627.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240628.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240629.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240630.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240701.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240702.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240703.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240704.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240705.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240706.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240707.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240708.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240709.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240710.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240711.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240712.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240713.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240714.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240715.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240716.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240717.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240718.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240719.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240720.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240721.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240722.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240723.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240724.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240725.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240726.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240727.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240728.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240729.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240730.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240731.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240801.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240802.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240803.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240804.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240805.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240806.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240807.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240808.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240809.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240810.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240811.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240812.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240813.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240814.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240815.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240816.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240817.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240818.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240819.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240820.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240821.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240822.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240823.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240824.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240825.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240826.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240827.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240828.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240829.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240830.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240831.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240901.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240902.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240903.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240904.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240905.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240906.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240907.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240908.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240909.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240910.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240911.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240912.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240913.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240914.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240915.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240916.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240917.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240918.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240919.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240920.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240921.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240922.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240923.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240924.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240925.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240926.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240927.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240928.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240929.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20240930.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241001.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241002.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241003.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241004.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241005.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241006.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241007.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241008.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241009.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241010.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241011.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241012.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241013.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241014.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241015.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241016.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241017.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241018.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241019.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241020.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241021.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241022.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241023.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241024.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241025.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241026.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241027.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241028.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241029.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241030.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241031.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241101.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241102.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241103.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241104.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241105.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241106.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241107.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241108.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241109.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241110.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241111.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241112.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241113.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241114.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241115.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241116.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241117.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241118.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241119.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241120.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241121.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241122.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241123.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241124.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241125.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241126.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241127.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241128.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241129.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241130.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241201.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241202.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241203.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241204.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241205.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241206.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241207.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241208.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241209.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241210.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241211.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241212.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241213.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241214.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241215.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241216.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241217.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241218.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241219.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241220.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241221.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241222.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241223.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241224.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241225.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241226.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241227.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241228.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241229.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241230.tif
# ✅ Exported /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Daily/NO2_500m_20241231.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-01.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-02.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-03.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-04.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-05.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-06.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-07.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-08.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-09.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-10.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-11.tif
# 📅 Exported monthly /content/drive/MyDrive/MAJOR_PROJECT/GeoTIFF_Monthly/NO2_500m_2024-12.tif
