# %%
import os
import pandas as pd

base_dir = "GroundTruth_Data"   # root folder containing 39 station subfolders

all_data = []

for station_folder in os.listdir(base_dir):
    station_path = os.path.join(base_dir, station_folder)

    if os.path.isdir(station_path):  # only go into folders
        for file in os.listdir(station_path):
            if file.endswith(".csv") or file.endswith(".xlsx"):
                file_path = os.path.join(station_path, file)

                # Read CSV or Excel
                if file.endswith(".csv"):
                    df = pd.read_csv(file_path)
                else:
                    df = pd.read_excel(file_path)

                # Standardize
                df["datetime"] = pd.to_datetime(df["From Date"], errors="coerce")
                df["date"] = df["datetime"].dt.date
                df["Station Name"] = station_folder  # assign folder as station name

                all_data.append(df[["Station Name", "date", "NO2"]])

# Combine all stations
cpcb = pd.concat(all_data, ignore_index=True)

# Daily mean per station
cpcb_daily = cpcb.groupby(["Station Name","date"])["NO2"].mean().reset_index()

print(cpcb_daily.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-830630877.py in <cell line: 0>()
#       6 all_data = []
#       7
# ----> 8 for station_folder in os.listdir(base_dir):
#       9     station_path = os.path.join(base_dir, station_folder)
#      10
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GroundTruth_Data'

# %%
import os
import pandas as pd
from google.colab import files
from google.colab import drive

# ============= OPTION 1: UPLOAD LOCAL FOLDER =============
# (You will upload a ZIP of your folder, we unzip it in Colab)
# def upload_local_folder():
#     print("Please upload a ZIP file containing the 'groundtruth' folder...")
#     uploaded = files.upload()
#     for fn in uploaded.keys():
#         print(f"Unzipping {fn} ...")
#         os.system(f"unzip -q {fn}")
#     return "groundtruth"   # assuming folder inside zip is named groundtruth


# ============= OPTION 2: USE GOOGLE DRIVE =============
def mount_drive_folder(folder_path="groundtruth"):
    drive.mount('/content/drive')
    base_dir = f"/content/drive/MyDrive/DELHI/GroundTruth_Data (1)"   # modify path if needed
    if not os.path.exists(base_dir):
        raise FileNotFoundError(f"{base_dir} not found in Drive!")
    return base_dir


# ============= MAIN PIPELINE =============
def load_groundtruth(base_dir):
    all_data = []

    for station_folder in os.listdir(base_dir):
        station_path = os.path.join(base_dir, station_folder)

        if os.path.isdir(station_path):
            for file in os.listdir(station_path):
                if file.endswith(".csv") or file.endswith(".xlsx"):
                    file_path = os.path.join(station_path, file)

                    # Read CSV or Excel
                    if file.endswith(".csv"):
                        df = pd.read_csv(file_path)
                    else:
                        df = pd.read_excel(file_path)

                    # Standardize
                    if "From Date" in df.columns:
                        df["datetime"] = pd.to_datetime(df["From Date"], errors="coerce")
                    elif "date" in df.columns:   # fallback
                        df["datetime"] = pd.to_datetime(df["date"], errors="coerce")
                    else:
                        continue

                    df["date"] = df["datetime"].dt.date
                    df["Station Name"] = station_folder

                    # Only keep NO2 column if present
                    if "NO2" in df.columns:
                        all_data.append(df[["Station Name", "date", "NO2"]])

    # Combine all stations
    cpcb = pd.concat(all_data, ignore_index=True)

    # Daily mean per station
    cpcb_daily = cpcb.groupby(["Station Name","date"])["NO2"].mean().reset_index()

    return cpcb_daily


# ============= RUN =============
# Uncomment ONE of the two options:

# 1. If you upload a ZIP manually
# base_dir = upload_local_folder()

# 2. If you use Google Drive
# base_dir = mount_drive_folder("groundtruth")

# Once chosen, load data
# cpcb_daily = load_groundtruth(base_dir)
# print(cpcb_daily.head())

# %%
import os
import pandas as pd
from google.colab import drive

# ============= MOUNT GOOGLE DRIVE =============
drive.mount('/content/drive')

# Path to your "groundtruth" folder in Google Drive
# Make sure you placed it inside MyDrive
base_dir = "/content/drive/MyDrive/DELHI/GroundTruth_Data (1)"

if not os.path.exists(base_dir):
    raise FileNotFoundError(f"{base_dir} not found! Please check path and folder name.")
else:
    print(f"✅ Base directory found: {base_dir}")

# ============= LOAD & PROCESS DATA =============
all_data = []

for station_folder in os.listdir(base_dir):
    station_path = os.path.join(base_dir, station_folder)
    print(f"Checking folder: {station_path}")

    if os.path.isdir(station_path):  # Only go into subfolders (stations)
        for file in os.listdir(station_path):
            print(f"  Checking file: {file}")
            if file.endswith(".csv") or file.endswith(".xlsx"):
                file_path = os.path.join(station_path, file)
                print(f"    Processing file: {file_path}")

                try:
                    # Read CSV or Excel
                    if file.endswith(".csv"):
                        df = pd.read_csv(file_path)
                    else:
                        df = pd.read_excel(file_path)

                    # Standardize datetime
                    date_column_found = False
                    if "From Date" in df.columns:
                        df["datetime"] = pd.to_datetime(df["From Date"], errors="coerce")
                        date_column_found = True
                    elif "date" in df.columns:
                        df["datetime"] = pd.to_datetime(df["date"], errors="coerce")
                        date_column_found = True
                    else:
                        print(f"      Skipping file: {file_path} - No 'From Date' or 'date' column found.")
                        continue  # skip if no recognizable date column

                    if not date_column_found:
                         print(f"      Skipping file: {file_path} - Datetime column not found or could not be parsed.")
                         continue


                    df["date"] = df["datetime"].dt.date
                    df["Station Name"] = station_folder  # Assign folder name as station

                    # Keep only required columns
                    if "NO2" in df.columns:
                        all_data.append(df[["Station Name", "date", "NO2"]])
                        print(f"      Added data from file: {file_path}")
                    else:
                        print(f"      Skipping file: {file_path} - No 'NO2' column found.")

                except Exception as e:
                    print(f"      Error processing file {file_path}: {e}")
                    continue


# Combine all stations into one dataframe
if all_data: # Check if all_data is not empty before concatenating
    cpcb = pd.concat(all_data, ignore_index=True)

    # Daily mean per station
    cpcb_daily = cpcb.groupby(["Station Name", "date"])["NO2"].mean().reset_index()

    # ============= SAVE OUTPUT =============
    output_path = "/content/drive/MyDrive/cpcb_daily.csv"
    cpcb_daily.to_csv(output_path, index=False)

    print("\n✅ Processing complete!")
    print(f"Saved file at: {output_path}")
    print(cpcb_daily.head())
else:
    print("\n❌ No data was processed from the specified directory. Please check the path, folder structure, file types, and column names.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Base directory found: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)
#   Checking file: oct (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/oct (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/oct (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: june (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/june (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/june (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Jan (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/Jan (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/Jan (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: dec (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/dec (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/dec (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: sept (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/sept (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/sept (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: may (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/may (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/may (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: nov (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/nov (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/nov (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: july (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/july (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/july (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: feb (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/feb (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/feb (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: march (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/march (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/march (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: april (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/april (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/april (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: aug (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/aug (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)/aug (1).xlsx - No 'From Date' or 'date' column found.
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)
#   Checking file: Apr_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Apr_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Apr_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Oct_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Oct_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Oct_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Dec_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Dec_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Dec_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Mar_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Mar_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Mar_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Nov_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Nov_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Nov_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Jan_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jan_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jan_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Dec_stadium(1) (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Dec_stadium(1) (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Dec_stadium(1) (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Aug_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Aug_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Aug_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Aug_stadium(1) (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Aug_stadium(1) (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Aug_stadium(1) (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Jun_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jun_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jun_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Sep_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Sep_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Sep_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Jan_stadium(1) (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jan_stadium(1) (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jan_stadium(1) (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Jul_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jul_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jul_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: May_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/May_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/May_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Feb_stadium (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Feb_stadium (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Feb_stadium (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Jun_stadium(1) (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jun_stadium(1) (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jun_stadium(1) (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Jul_stadium(1) (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jul_stadium(1) (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Jul_stadium(1) (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Apr_stadium(1) (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Apr_stadium(1) (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Apr_stadium(1) (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Feb_stadium(1) (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Feb_stadium(1) (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Major Dhyanchand National Stadium (1)/Feb_stadium(1) (1).xlsx - No 'From Date' or 'date' column found.
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)
#   Checking file: September_MandirMarg (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/September_MandirMarg (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/September_MandirMarg (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: May_MandiraMarg (2).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/May_MandiraMarg (2).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/May_MandiraMarg (2).xlsx - No 'From Date' or 'date' column found.
#   Checking file: February_MandiraMarg (2).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/February_MandiraMarg (2).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/February_MandiraMarg (2).xlsx - No 'From Date' or 'date' column found.
#   Checking file: January_MandiraMarg (3).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/January_MandiraMarg (3).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/January_MandiraMarg (3).xlsx - No 'From Date' or 'date' column found.
#   Checking file: May_MandiraMarg (3).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/May_MandiraMarg (3).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/May_MandiraMarg (3).xlsx - No 'From Date' or 'date' column found.
#   Checking file: March_MandiraMarg (3).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/March_MandiraMarg (3).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/March_MandiraMarg (3).xlsx - No 'From Date' or 'date' column found.
#   Checking file: July_MandirMarg (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/July_MandirMarg (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/July_MandirMarg (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: January_MandiraMarg (4).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/January_MandiraMarg (4).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/January_MandiraMarg (4).xlsx - No 'From Date' or 'date' column found.
#   Checking file: November_MandirMarg (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/November_MandirMarg (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/November_MandirMarg (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: August_MandirMarg (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/August_MandirMarg (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/August_MandirMarg (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: June_MandirMarg (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/June_MandirMarg (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/June_MandirMarg (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: October_MandirMarg (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/October_MandirMarg (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/October_MandirMarg (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: April_MandiraMarg (3).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/April_MandiraMarg (3).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/April_MandiraMarg (3).xlsx - No 'From Date' or 'date' column found.
#   Checking file: December_MandirMarg (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/December_MandirMarg (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/December_MandirMarg (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: January_MandiraMarg (5).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/January_MandiraMarg (5).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/January_MandiraMarg (5).xlsx - No 'From Date' or 'date' column found.
#   Checking file: February_MandiraMarg (3).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/February_MandiraMarg (3).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/February_MandiraMarg (3).xlsx - No 'From Date' or 'date' column found.
#   Checking file: April_MandiraMarg (2).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/April_MandiraMarg (2).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/April_MandiraMarg (2).xlsx - No 'From Date' or 'date' column found.
#   Checking file: March_MandiraMarg (2).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/March_MandiraMarg (2).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Mandira_Marg (1)/March_MandiraMarg (2).xlsx - No 'From Date' or 'date' column found.
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/RK_Puram-20250801T150605Z-1-001 (1).zip
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)
#   Checking file: January_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/January_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/January_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: February_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/February_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/February_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: March_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/March_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/March_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: April_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/April_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/April_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: May_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/May_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/May_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: June_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/June_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/June_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: July_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/July_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/July_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: August_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/August_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/August_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: September_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/September_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/September_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: October_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/October_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/October_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: November_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/November_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/November_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: December_Aya_Nagar (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/December_Aya_Nagar (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Aya_Nagar (1)/December_Aya_Nagar (1).xlsx - No 'From Date' or 'date' column found.
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Dr (1).karni
#   Checking file: Dr (1).karni
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)
#   Checking file: Nov_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Nov_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Nov_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Dec_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Dec_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Dec_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: May_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/May_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/May_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: April_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/April_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/April_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: June_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/June_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/June_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Aug_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Aug_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Aug_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Oct_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Oct_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Oct_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Sep_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Sep_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Sep_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Fab_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Fab_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Fab_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: July_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/July_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/July_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: March_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/March_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/March_alipur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Jan_alipur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Jan_alipur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Alipur (1)/Jan_alipur (1).xlsx - No 'From Date' or 'date' column found.
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Bawana (1)
#   Checking file: January_Bawanna (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Bawana (1)/January_Bawanna (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Bawana (1)/January_Bawanna (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: February-Bawana (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Bawana (1)/February-Bawana (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Bawana (1)/February-Bawana (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: March_-Bawana (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Bawana (1)
1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sonia vihar (1)/Oct_sonia vihar (1).xlsx - No 'From Date' or 'date' column found.
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)
#   Checking file: February (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/February (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/February (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: August (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/August (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/August (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: June (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/June (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/June (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: March (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/March (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/March (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: April (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/April (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/April (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: November (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/November (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/November (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: January (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/January (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/January (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: May (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/May (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/May (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: July (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/July (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/July (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: September (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/September (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/September (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: December (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/December (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/December (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: October (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/October (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Sri Aurobindo marg (1)/October (1).xlsx - No 'From Date' or 'date' column found.
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)
#   Checking file: July (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/July (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/July (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: February (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/February (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/February (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: August (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/August (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/August (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: January (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/January (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/January (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: October (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/October (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/October (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: April (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/April (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/April (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: December (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/December (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/December (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: November (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/November (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/November (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: May (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/May (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/May (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: June (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/June (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/June (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: September (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/September (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/September (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: March (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/March (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Vivek Vihar (1)/March (1).xlsx - No 'From Date' or 'date' column found.
# Checking folder: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)
#   Checking file: Nov_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Nov_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Nov_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: March_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/March_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/March_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Oct_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Oct_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Oct_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: May_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/May_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/May_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Sept_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Sept_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Sept_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Feb_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Feb_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Feb_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: June_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/June_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/June_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Dec_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Dec_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Dec_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Jan_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Jan_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Jan_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: Aug_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Aug_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/Aug_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: July_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/July_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/July_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#   Checking file: April_Wazirpur (1).xlsx
#     Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/April_Wazirpur (1).xlsx
#       Skipping file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/April_Wazirpur (1).xlsx - No 'From Date' or 'date' column found.
#
# ❌ No data was processed from the specified directory. Please check the path, folder structure, file types, and column names.

# %%
import os
import pandas as pd
from google.colab import drive

# ============= MOUNT GOOGLE DRIVE =============
drive.mount('/content/drive')

# Path to your "groundtruth" folder in Google Drive
base_dir = "/content/drive/MyDrive/DELHI/GroundTruth_Data (1)"

if not os.path.exists(base_dir):
    raise FileNotFoundError(f"{base_dir} not found! Please check path and folder name.")

# ============= LOAD & PROCESS DATA =============
all_data = []

for station_folder in os.listdir(base_dir):
    station_path = os.path.join(base_dir, station_folder)

    if os.path.isdir(station_path):  # Only go into subfolders (stations)
        for file in os.listdir(station_path):
            if file.endswith(".csv") or file.endswith(".xlsx"):
                file_path = os.path.join(station_path, file)
                print(f"Processing file: {file_path}")

                try:
                    if file.endswith(".csv"):
                        df = pd.read_csv(file_path)
                    else:
                        # Skip first 16 rows so that A17 becomes header
                        df = pd.read_excel(file_path, skiprows=16)

                    # Ensure proper datetime column
                    if "From Date" in df.columns:
                        df["datetime"] = pd.to_datetime(df["From Date"], errors="coerce")
                    elif "date" in df.columns:
                        df["datetime"] = pd.to_datetime(df["date"], errors="coerce")
                    else:
                        print(f"  Skipping file: {file_path} - No 'From Date' or 'date' column found.")
                        continue

                    df["date"] = df["datetime"].dt.date
                    df["Station Name"] = station_folder

                    # Ensure NO2 column exists
                    if "NO2" in df.columns:
                        all_data.append(df[["Station Name", "date", "NO2"]])
                    else:
                        print(f"  Skipping file: {file_path} - NO2 column not found.")

                except Exception as e:
                    print(f"  Error processing {file_path}: {e}")

# Combine all stations
if all_data:
    cpcb = pd.concat(all_data, ignore_index=True)
    # Daily mean per station
    cpcb_daily = cpcb.groupby(["Station Name","date"])["NO2"].mean().reset_index()

    # ============= SAVE OUTPUT =============
    output_path = "/content/drive/MyDrive/cpcb_daily.csv"
    cpcb_daily.to_csv(output_path, index=False)

    print("✅ Processing complete!")
    print(f"Saved file at: {output_path}")
    print(cpcb_daily.head())
else:
    print("⚠️ No valid files were processed. Check headers/columns again.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Najafgarh (1)
Wazirpur (1).xlsx
# Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/July_Wazirpur (1).xlsx
# Processing file: /content/drive/MyDrive/DELHI/GroundTruth_Data (1)/Wazirpur (1)/April_Wazirpur (1).xlsx
# ✅ Processing complete!
# Saved file at: /content/drive/MyDrive/cpcb_daily.csv
#   Station Name        date        NO2
# 0   Alipur (1)  2024-01-01  24.790417
# 1   Alipur (1)  2024-01-02  22.765417
# 2   Alipur (1)  2024-01-03  51.971667
# 3   Alipur (1)  2024-01-04  14.457917
# 4   Alipur (1)  2024-01-05  19.005000

# %%
import pandas as pd
import geopandas as gpd
import ast
import os
from shapely.geometry import Point

# --------------------
# STEP 1: Load CPCB daily groundtruth
# --------------------
cpcb = pd.read_csv("/content/drive/MyDrive/DELHI/cpcb_daily.csv")
cpcb["date"] = pd.to_datetime(cpcb["date"])
cpcb["month"] = cpcb["date"].dt.to_period("M")  # YYYY-MM
cpcb_monthly = cpcb.groupby(["Station Name","month"])["NO2"].mean().reset_index()

# --------------------
# STEP 2: Load station locations
# --------------------
stations = pd.read_csv("/content/drive/MyDrive/DELHI/delhi_station_population_2024.csv")
gdf_stations = gpd.GeoDataFrame(
    stations,
    geometry=gpd.points_from_xy(stations["Longitude"], stations["Latitude"]),
    crs="EPSG:4326"
)

# --------------------
# STEP 3: Function to parse one satellite file
# --------------------
def parse_satellite_file(file_path, month_str):
    sat = pd.read_csv(file_path)

    # Parse lat/lon from geo column
    def parse_coords(geo_str):
        try:
            geo_dict = ast.literal_eval(geo_str)
            return geo_dict["coordinates"][0], geo_dict["coordinates"][1]
        except:
            return None, None

    sat[["lon", "lat"]] = sat[".geo"].apply(lambda g: pd.Series(parse_coords(g)))

    gdf_sat = gpd.GeoDataFrame(
        sat,
        geometry=gpd.points_from_xy(sat["lon"], sat["lat"]),
        crs="EPSG:4326"
    )

    # nearest join
    joined = gpd.sjoin_nearest(gdf_stations, gdf_sat, how="left")

    # assign month
    joined["month"] = month_str

    return joined[["STATION NAME", "month", "tropospheric_NO2_column_number_density"]]

# --------------------
# STEP 4: Loop over all satellite monthly files
# --------------------
sat_dir = "/content/drive/MyDrive/DELHI/Delhi_NO2_Daily_Satellite"
all_sat = []

for file in os.listdir(sat_dir):
    if file.endswith(".csv"):
        # Extract month from filename
        # Example: "TROPOMI_NO2_Delhi_April2024.csv"
        month_name = file.split("_")[-1].replace(".csv","")  # e.g. "April2024"
        month_str = pd.to_datetime(month_name, format="%B%Y").to_period("M")  # YYYY-MM

        print(f"Processing {file} as {month_str}")
        sat_data = parse_satellite_file(os.path.join(sat_dir, file), month_str)
        all_sat.append(sat_data)

satellite_all = pd.concat(all_sat, ignore_index=True)

# --------------------
# STEP 5: Merge CPCB monthly averages with satellite
# --------------------
final = pd.merge(
    cpcb_monthly,
    satellite_all,
    left_on=["Station Name","month"],
    right_on=["STATION NAME","month"],
    how="inner"
)

final.to_csv("/content/drive/MyDrive/DELHI/merged_NO2_station_satellite.csv", index=False)
print("✅ Final merged dataset saved!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-668483500.py in <cell line: 0>()
#       8 # STEP 1: Load CPCB daily groundtruth
#       9 # --------------------
# ---> 10 cpcb = pd.read_csv("/content/drive/MyDrive/DELHI/cpcb_daily.csv")
#      11 cpcb["date"] = pd.to_datetime(cpcb["date"])
#      12 cpcb["month"] = cpcb["date"].dt.to_period("M")  # YYYY-MM
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/DELHI/cpcb_daily.csv'
